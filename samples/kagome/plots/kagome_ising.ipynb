# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.rcParams.update({
    'font.size': 20,
    'lines.linewidth': 2,
    'lines.markersize': 8,
})

# %%
df = pd.read_csv('../data/kagome_ising_hx_sweep.csv')
df.head()
# Out:
#     hx    energy            mx        mz
# 0  0.0 -1.500000  3.162347e-14  1.000000
# 1  0.1 -1.503750  5.002098e-02  0.998748
# 2  0.2 -1.514993  1.001685e-01  0.994965
# 3  0.3 -1.533712  1.505756e-01  0.988569
# 4  0.4 -1.559874  2.013880e-01  0.979413

# %%
plt.figure(0, [6.25, 3.5])

plt.gca().set_clip_on(False)
line1, = plt.plot(df["hx"], df["mz"], '-ob', label="$\\langle \\sigma_z \\rangle$", zorder=3)
line1.set_clip_on(False)
line2, = plt.plot(df["hx"], df["mx"], '-or', label="$\\langle \\sigma_x \\rangle$", zorder=3)
line2.set_clip_on(False)

plt.axvline(x=2.95265/2, color='black', linestyle='--', linewidth=2)

plt.legend(loc='center left', fontsize=16)
plt.xlabel('$h_x$')

plt.xlim(0,2)
plt.ylim(0,1)

plt.savefig("kagome_hx.pdf", format="pdf", dpi=300, bbox_inches="tight")
plt.show()
